# %%
# !git clone https://github.com/sunanhe/MKT.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: download with gdown

# !gdown 158ntqLvepVklwmY1PvlqIhguv7wN6SZI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=158ntqLvepVklwmY1PvlqIhguv7wN6SZI
# To: /content/first_stage_best_model_nus.pth
# 100% 347M/347M [00:05<00:00, 62.6MB/s]

# %%
# !mv /content/MKT /content/drive/MyDrive

# %%
# pip install -r /content/drive/MyDrive/MKT/requirements.txt

# %%
# !wget https://openaipublic.azureedge.net/clip/models/5806e77cd80f8b59890b7e101eabd078d9fb84e6937f9e85e4ecb61988df416f/ViT-B-16.pt -P  /content/drive/MyDrive/MKT/
# Out:
# --2023-12-05 16:50:55--  https://openaipublic.azureedge.net/clip/models/5806e77cd80f8b59890b7e101eabd078d9fb84e6937f9e85e4ecb61988df416f/ViT-B-16.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.69, 13.107.213.69, 2620:1ec:bdf::69, ...
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 350837078 (335M) [application/octet-stream]
# /content/drive/MyDrive/MKT/ViT-B-16.pt.1: Read-only file system
#
# Cannot write to ‘/content/drive/MyDrive/MKT/ViT-B-16.pt.1’ (Success).

# %%
# !wget https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/NUS_WID_Low_Level_Features.rar -P /content/drive/MyDrive/MKT/dataset
# Out:
# --2023-12-05 01:15:07--  https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/NUS_WID_Low_Level_Features.rar
# Resolving lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)... 137.132.84.196
# Connecting to lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)|137.132.84.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1177018873 (1.1G)
# Saving to: ‘/content/drive/MyDrive/MKT/dataset/NUS_WID_Low_Level_Features.rar.2’
#
#              NUS_WI  34%[=====>              ] 387.84M   371KB/s    eta 33m 53s^C

# %%
# !wget https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/Groundtruth.zip -P /content/drive/MyDrive/MKT/dataset
# Out:
# --2023-12-05 01:12:48--  https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/Groundtruth.zip
# Resolving lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)... 137.132.84.196
# Connecting to lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)|137.132.84.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1129480 (1.1M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/MKT/dataset/Groundtruth.zip’
#
# Groundtruth.zip     100%[===================>]   1.08M   330KB/s    in 3.3s
#
# 2023-12-05 01:12:52 (330 KB/s) - ‘/content/drive/MyDrive/MKT/dataset/Groundtruth.zip’ saved [1129480/1129480]

# %%
# !wget https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/NUS_WID_Tags.zip -P /content/drive/MyDrive/MKT/dataset
# Out:
# --2023-12-05 01:12:53--  https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/NUS_WID_Tags.zip
# Resolving lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)... 137.132.84.196
# Connecting to lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)|137.132.84.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26398043 (25M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/MKT/dataset/NUS_WID_Tags.zip’
#
# NUS_WID_Tags.zip    100%[===================>]  25.17M   374KB/s    in 69s
#
# 2023-12-05 01:14:02 (375 KB/s) - ‘/content/drive/MyDrive/MKT/dataset/NUS_WID_Tags.zip’ saved [26398043/26398043]

# %%
# !wget https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/ConceptsList.zip -P /content/drive/MyDrive/MKT/dataset
# Out:
# --2023-12-05 01:14:03--  https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/ConceptsList.zip
# Resolving lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)... 137.132.84.196
# Connecting to lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)|137.132.84.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 448 [application/zip]
# Saving to: ‘/content/drive/MyDrive/MKT/dataset/ConceptsList.zip’
#
# ConceptsList.zip    100%[===================>]     448  --.-KB/s    in 0s
#
# 2023-12-05 01:14:04 (125 MB/s) - ‘/content/drive/MyDrive/MKT/dataset/ConceptsList.zip’ saved [448/448]

# %%
# !wget https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/ImageList.zip -P /content/drive/MyDrive/MKT/dataset
# Out:
# --2023-12-05 01:14:04--  https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/ImageList.zip
# Resolving lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)... 137.132.84.196
# Connecting to lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)|137.132.84.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4467515 (4.3M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/MKT/dataset/ImageList.zip’
#
# ImageList.zip       100%[===================>]   4.26M   351KB/s    in 13s
#
# 2023-12-05 01:14:18 (343 KB/s) - ‘/content/drive/MyDrive/MKT/dataset/ImageList.zip’ saved [4467515/4467515]

# %%
# !wget https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/NUS-WIDE-urls.rar -P /content/drive/MyDrive/MKT/dataset
# Out:
# --2023-12-05 01:14:18--  https://lms.comp.nus.edu.sg/wp-content/uploads/2019/research/nuswide/NUS-WIDE-urls.rar
# Resolving lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)... 137.132.84.196
# Connecting to lms.comp.nus.edu.sg (lms.comp.nus.edu.sg)|137.132.84.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9120747 (8.7M)
# Saving to: ‘/content/drive/MyDrive/MKT/dataset/NUS-WIDE-urls.rar’
#
# NUS-WIDE-urls.rar   100%[===================>]   8.70M   371KB/s    in 24s
#
# 2023-12-05 01:14:44 (364 KB/s) - ‘/content/drive/MyDrive/MKT/dataset/NUS-WIDE-urls.rar’ saved [9120747/9120747]

# %%
# !wget https://github.com/akshitac8/BiAM.git
# Out:
# --2023-12-05 02:05:49--  https://github.com/akshitac8/BiAM.git
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/akshitac8/BiAM [following]
# --2023-12-05 02:05:49--  https://github.com/akshitac8/BiAM
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘BiAM.git’
#
# BiAM.git                [ <=>                ] 259.17K  --.-KB/s    in 0.03s
#
# 2023-12-05 02:05:50 (8.64 MB/s) - ‘BiAM.git’ saved [265391]

# %%
# !python3 /content/BiAM-main/feature_extraction/extract_nus_wide.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Net(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ...

# %%
# !unzip /content/BiAM-main.zip
# Out:
# Archive:  /content/BiAM-main.zip
# 4e391f1a7bb0de86f7fc274e5c99c2b92b9cf955
#    creating: BiAM-main/
#   inflating: BiAM-main/.gitignore
#   inflating: BiAM-main/LICENSE
#   inflating: BiAM-main/README.md
#   inflating: BiAM-main/config.py
#    creating: BiAM-main/datasets/
#    creating: BiAM-main/datasets/NUS-WIDE/
#    creating: BiAM-main/datasets/NUS-WIDE/ConceptsList/
#   inflating: BiAM-main/datasets/NUS-WIDE/ConceptsList/Concepts81.txt
#    creating: BiAM-main/datasets/NUS-WIDE/NUS_WID_Tags/
#   inflating: BiAM-main/datasets/NUS-WIDE/NUS_WID_Tags/TagList1k.txt
#   inflating: BiAM-main/datasets/NUS-WIDE/img_names.pkl
#   inflating: BiAM-main/datasets/NUS-WIDE/test_img_names.pkl
#    creating: BiAM-main/datasets/NUS-WIDE/wiki_contexts/
#   inflating: BiAM-main/datasets/NUS-WIDE/wiki_contexts/NUS_WIDE_pretrained_w2v_glove-wiki-gigaword-300
#    creating: BiAM-main/datasets/OpenImages/
#    creating: BiAM-main/datasets/OpenImages/2018_04/
# ...

# %%
# !unzip /content/drive/MyDrive/MKT/dataset/archive.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/NUS-WIDE/images/0653_2197815803.jpg
#   inflating: /content/NUS-WIDE/images/0653_2198634882.jpg
#   inflating: /content/NUS-WIDE/images/0653_2200124378.jpg
#   inflating: /content/NUS-WIDE/images/0653_2259712600.jpg
#   inflating: /content/NUS-WIDE/images/0653_2264001121.jpg
#   inflating: /content/NUS-WIDE/images/0653_2269451685.jpg
#   inflating: /content/NUS-WIDE/images/0653_2276095977.jpg
#   inflating: /content/NUS-WIDE/images/0653_2279436158.jpg
#   inflating: /content/NUS-WIDE/images/0653_2280745412.jpg
#   inflating: /content/NUS-WIDE/images/0653_2282846243.jpg
#   inflating: /content/NUS-WIDE/images/0653_2295984552.jpg
#   inflating: /content/NUS-WIDE/images/0653_2296143546.jpg
#   inflating: /content/NUS-WIDE/images/0653_2299437190.jpg
#   inflating: /content/NUS-WIDE/images/0653_2311060082.jpg
#   inflating: /content/NUS-WIDE/images/0653_2314451897.jpg
# ...

# %%
# !pip3 install -r /content/drive/MyDrive/MKT/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 26.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.2/763.2 kB 52.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 52.5 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement torch==1.9.0 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1)
# ERROR: No matching distribution found for torch==1.9.0

# %%
# !pip3 install pytest-runner --upgrade

# !pip3 install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 15.4 MB/s eta 0:00:00
# ...

# %%
# !pip3 install ftfy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !python3 /content/drive/MyDrive/MKT/train_nus_first_stage.py         --data-path /content/drive/MyDrive/MKT/dataset   --clip-path /content/drive/MyDrive/MKT/ViT-B-16.pt
# Out:
# 100% 2527/2527 [16:28<00:00,  2.56it/s]
# 100% 229/229 [06:19<00:00,  1.66s/it]
# 100% 2527/2527 [14:28<00:00,  2.91it/s]
# 100% 229/229 [06:12<00:00,  1.63s/it]
# 100% 2527/2527 [14:29<00:00,  2.91it/s]
# 100% 229/229 [06:12<00:00,  1.62s/it]
# 100% 2527/2527 [14:29<00:00,  2.91it/s]
# 100% 229/229 [06:11<00:00,  1.62s/it]
# 100% 2527/2527 [14:29<00:00,  2.91it/s]
# 100% 229/229 [06:11<00:00,  1.62s/it]
# 100% 2527/2527 [14:28<00:00,  2.91it/s]
# 100% 229/229 [06:11<00:00,  1.62s/it]
# 100% 2527/2527 [14:29<00:00,  2.91it/s]
# 100% 229/229 [06:11<00:00,  1.62s/it]
# 100% 2527/2527 [14:29<00:00,  2.91it/s]
# 100% 229/229 [06:11<00:00,  1.62s/it]
# 100% 2527/2527 [14:29<00:00,  2.91it/s]
# 100% 229/229 [06:10<00:00,  1.62s/it]
# 100% 2527/2527 [14:25<00:00,  2.92it/s]
# 100% 229/229 [06:10<00:00,  1.62s/it]
# 100% 2527/2527 [14:25<00:00,  2.92it/s]
# 100% 229/229 [06:11<00:00,  1.62s/it]
#  50% 1276/2527 [07:19<07:11,  2.90it/s]
# Traceback (most recent call last):
# ...

# %%
# !cp /content/outputs/first_stage/12-05-17:02:21_MKT/model_epoch_10.pth /content/drive/MyDrive/MKT
# Out:
# cp: cannot create regular file '/content/drive/MyDrive/MKT/model_epoch_10.pth': Read-only file system

# %%
/content/drive/MyDrive/MKT/train_nus_second_stage.py \
        --data-path  /content/drive/MyDrive/MKT/dataset \
        --clip-path  /content/drive/MyDrive/MKT/ViT-B-16.pt \
        --ckpt-path /content/drive/MyDrive/model_epoch_10.pth

# %%
# !gdown 1TBh1eWDLhHTjTfnRRfZULpe4DfPj7u9O
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TBh1eWDLhHTjTfnRRfZULpe4DfPj7u9O
# To: /content/second_stage_best_model_nus.pth
# 100% 254M/254M [00:01<00:00, 146MB/s]

# %% [markdown]
# **PAPER RESULTS**

# %%
# !python3 /content/drive/MyDrive/MKT/train_nus_second_stage.py --eval --data-path /content/drive/MyDrive/MKT/dataset --clip-path /content/drive/MyDrive/MKT/ViT-B-16.pt --ckpt-path /content/first_stage_best_model_nus.pth --eval-ckpt /content/second_stage_best_model_nus.pth
# Out:
# Image Encoder Load Info:  <All keys matched successfully>
# Text Encoder Load Info:  <All keys matched successfully>
# =======================EVALUATION MODE=======================
# 100% 229/229 [04:24<00:00,  1.16s/it]
# > /content/drive/.shortcut-targets-by-id/1BIgjkhhFEzYo725GlLY3U4Knb9OO3Uno/MKT/engine_nus_second_stage.py(190)eval()
# -> print("completed calculating predictions over all images")
# (Pdb) c
# completed calculating predictions over all images
# ZSL AP: 0.4253
# k=3: 0.3413,0.2773,0.4434
# k=5: 0.3151,0.2167,0.5773
# GZSL AP: 0.2149
# g_k=3: 0.2412,0.3942,0.1738
# g_k=5: 0.2786,0.3289,0.2416

# %%
# !python3 /content/drive/MyDrive/MKT/inference.py \
        --data-path /content/drive/MyDrive/MKT/dataset \
        --clip-path /content/drive/MyDrive/MKT/ViT-B-16.pt \
        --img-ckpt  /content/drive/MyDrive/model_epoch_10.pth \
        --txt-ckpt /content/second_stage_best_model_nus.pth \
        --image-path figures/test.jpg

# %% [markdown]
# **MY RESULTS**

# %%
# !python3 /content/drive/MyDrive/MKT/train_nus_second_stage.py --eval --data-path /content/drive/MyDrive/MKT/dataset --clip-path /content/drive/MyDrive/MKT/ViT-B-16.pt --ckpt-path /content/drive/MyDrive/model_epoch_10.pth --eval-ckpt /content/second_stage_best_model_nus.pth
# Out:
# Image Encoder Load Info:  <All keys matched successfully>
# Text Encoder Load Info:  <All keys matched successfully>
# =======================EVALUATION MODE=======================
# 100% 229/229 [02:24<00:00,  1.59it/s]
# > /content/drive/.shortcut-targets-by-id/1BIgjkhhFEzYo725GlLY3U4Knb9OO3Uno/MKT/engine_nus_second_stage.py(190)eval()
# -> print("completed calculating predictions over all images")
# (Pdb) c
# completed calculating predictions over all images
# ZSL AP: 0.4039
# k=3: 0.3365,0.2734,0.4372
# k=5: 0.3110,0.2139,0.5699
# GZSL AP: 0.2050
# g_k=3: 0.2331,0.3810,0.1679
# g_k=5: 0.2694,0.3181,0.2337

# %%
# !python3 /content/drive/MyDrive/MKT/inference.py --data-path /content/drive/MyDrive/MKT/dataset --clip-path /content/drive/MyDrive/MKT/ViT-B-16.pt --img-ckpt /content/drive/MyDrive/model_epoch_10.pth --txt-ckpt /content/second_stage_best_model_nus.pth --image-path /content/drive/MyDrive/MKT/figures/test.jpg
# Out:
# Image Encoder Load Info:  <All keys matched successfully>
# Text Encoder Load Info:  <All keys matched successfully>
# Top-10 Predictions:
# california          0.5102
# bicycle             0.2908
# bike                0.2258
# palm                0.1920
# tree                0.1273
# street              0.1210
# sidewalk            0.1081
# sunset              0.1024
# night               0.0994
# city                0.0993

# %%
# prompt: read and print line by line from log

with open('/content/outputs/first_stage/12-10-21:26:34_MKT/recording.log', 'r', encoding='utf-8') as f:
    for line in f:
        print(line)
# Out:
# 2023-12-10 21:26:56,874 - engine_nus_first_stage.py[line:12] - INFO: TRAINING MODE
#
# 2023-12-10 21:43:25,307 - engine_nus_first_stage.py[line:60] - INFO: ------------------------------------------------------------------
#
# 2023-12-10 21:43:25,307 - engine_nus_first_stage.py[line:61] - INFO: FINETUNING Epoch: 0/20 	RankLoss: 0.951544	DistLoss: 0.035611	LearningRate 0.0004998021369212505
#
# 2023-12-10 21:43:25,307 - engine_nus_first_stage.py[line:62] - INFO: ------------------------------------------------------------------
#
# 2023-12-10 21:43:25,755 - engine_nus_first_stage.py[line:70] - INFO: =======================EVALUATION MODE=======================
#
# 2023-12-10 21:49:44,888 - engine_nus_first_stage.py[line:105] - INFO: completed calculating predictions over all images
#
# 2023-12-10 21:49:45,020 - engine_nus_first_stage.py[line:111] - INFO: ZSL AP: 0.3700
#
# 2023-12-10 21:49:45,021 - engine_nus_first_stage.py[line:112] - INFO: k=3: 0.3063,0.2490,0.3981
#
# ...
